# %% [markdown]
# # 04 — Model Training
#
# Train XGBoost and MLP classifiers with subject-level train/test splits.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

from classifier_models.train_XGBoost import train_xgboost
from classifier_models.train_mlp import train_mlp

# %%
_, xgb_metrics = train_xgboost(n_iter=5, cv=3)
xgb_metrics

# %%
_, _, mlp_metrics = train_mlp()
mlp_metrics
